# %% [markdown]
# <a href="https://colab.research.google.com/github/mt8951/Sign-Up/blob/main/internship_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PORJECT NAME : MONKEY POX ANALYSIS

# %% [markdown]
# #DEFINITION :
#
# Monkeypox is an infectious viral disease that can occur in humans and some other animals. The disease is caused by monkeypox virus, a zoonotic virus in the genus Orthopoxvirus. An ongoing outbreak of this viral disease monkeypox was confirmed in May 2022, beginning with a cluster of cases found in the United Kingdom. The first confirmed case was traced to an individual with travel links to Nigeria (where the disease is endemic) and was detected on 6 May 2022, although it has been suggested tha
# ``Monkeypox is an infectious viral disease that can occur in humans and some other animals. The disease is caused by monkeypox virus, a zoonotic virus in the genus Orthopoxvirus. An ongoing outbreak of this viral disease monkeypox was confirmed in May 2022, beginning with a cluster of cases found in the United Kingdom. The first confirmed case was traced to an individual with travel links to Nigeria (where the disease is endemic) and was detected on 6 May 2022, although it has been suggested that cases were already spreading in the previous months. From 18 May onwards, cases were reported from an increasing number of countries and regions, predominantly in Europe, but also in North and South America, Asia, Africa and Australia. As of 27 June, the World Health Organization has declared this an "Evolving Health Threat" rather than a Public Health Emergency of International Concern (PHEIC).

# %% [markdown]
# #PROJECT SUMMARY :
#  The primary objective of this project is to analyze the spread, impact, and control measures of monkeypox virus outbreaks. This includes understanding the epidemiology, transmission patterns, clinical features, and effectiveness of various interventions.

# %% [markdown]
# #OBJECTIVES:
# To analyze the spread, impact, and control measures of monkeypox outbreaks, focusing on epidemiology, transmission patterns, clinical features, and intervention effectiveness.
#
#
#
# #KEY COMPONENTS:
#
# 1.Epidemiological Analysis
#    Data Collection: Aggregating data on monkeypox cases from health records,
#                      hospital reports, and international organizations.
#    Trend Analysis: Examining incidence and prevalence over time and across regions.
#    Risk Factors: Identifying factors contributing to the transmission of monkeypox.
#
# 2.Transmission Dynamics:
#    Mode of Transmission: Investigating primary and secondary transmission routes.
#    Transmission Networks: Mapping the spread within and between communities.
#    Infection Rates: Calculating the basic reproduction number (R0).
#
# 3.Clinical Features:
#    Symptomatology: Documenting clinical presentations in different populations.
#    Complications: Identifying common complications and outcomes.
#    Pathophysiology: Exploring disease development mechanisms.
#
# 4.Public Health Interventions:
#    Vaccination: Evaluating the effectiveness of smallpox vaccines against monkeypox.
#    Containment Measures: Assessing the impact of quarantine, isolation, and travel restrictions.
#    Public Awareness: Studying the role of education campaigns in preventing spread.
#
# 5.Public Health Interventions:
#    Vaccination Strategies: Evaluating the effectiveness of existing smallpox vaccines against monkeypox.
#    Containment Measures: Assessing the impact of quarantine, isolation, and travel restrictions on controlling outbreaks.
#    Public Awareness: Studying the role of public education campaigns in preventing monkeypox spread.
#
# 6.Genomic Analysis:
#    Virus Sequencing: Conducting genomic sequencing of monkeypox virus samples to track mutations and variants.
#    Phylogenetic Studies: Analyzing the evolutionary relationships between different monkeypox virus strains.
#    Genetic Markers: Identifying genetic markers associated with virulence and transmission.

# %% [markdown]
# #**PROBLEM STATEMENTS**
#
# 1. Limited understanding of the transmission dynamics of monkeypox within human populations.
#
# 2. Challenges in accurately diagnosing and differentiating monkeypox from other similar diseases.
#
# 3. Insufficient surveillance systems to detect and monitor monkeypox outbreaks in endemic regions.
#
# 4. Lack of standardized protocols for reporting and investigating suspected monkeypox cases.
#
# 5. Difficulty in assessing the impact of animal reservoirs on human monkeypox infections.
#
# 6. Inadequate knowledge of risk factors contributing to monkeypox transmission in urban and rural settings.
#
# 7. Limited availability of genomic data for studying the genetic diversity and evolution of monkeypox virus strains.
#
# 8. Challenges in predicting the geographic spread and potential hotspots of monkeypox outbreaks.
#
# 9. Insufficient resources for rapid response and containment of monkeypox outbreaks in affected areas.
#
# 10. Lack of effective communication strategies to educate communities about monkeypox prevention and control measures.
#
# 11. Difficulty in assessing the effectiveness of vaccination campaigns in reducing monkeypox incidence.
#
# 12. Inequities in access to healthcare services leading to underreporting and delayed diagnosis of monkeypox cases.
#
# 13. Limited understanding of the long-term health impacts and sequelae of monkeypox infection.
#
# 14. Challenges in studying the role of environmental factors in monkeypox transmission dynamics.
#
# 15. Insufficient research on potential animal-to-human transmission routes of monkeypox virus.
#
# 16. Lack of coordination among healthcare agencies and stakeholders involved in monkeypox surveillance and response efforts.
#
# 17. Difficulty in implementing targeted interventions to prevent monkeypox outbreaks in high-risk populations.
#
# 18. Inadequate training and capacity-building programs for healthcare workers in endemic regions to manage monkeypox cases.
#
# 19. Limited access to antiviral medications and supportive care for patients with severe monkeypox symptoms.
#
# 20. Challenges in assessing the economic burden of monkeypox outbreaks on healthcare systems and affected communities.

# %% [markdown]
# #IMPORTING THE NESESSARY LIBRABRIES
#
# Pandas – This library helps to load the data frame in a 2D array format and has multiple functions to perform analysis tasks in one go.
#
# Numpy – Numpy arrays are very fast and can perform large computations in a very short time.
#
# Matplotlib/Seaborn – This library is used to draw visualizations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #LOAD THE MONKEY POX DISEASE DATASET

# %%
case = pd.read_csv("/content/Monkey_Pox_Cases_Worldwide (1).csv")
case_timeline =pd.read_csv("/content/Worldwide_Case_Detection_Timeline (1).csv")
case_country = pd.read_csv("/content/Daily_Country_Wise_Confirmed_Cases (1).csv")

# %% [markdown]
# **Monkey_Pox_Cases_Worldwide :** This dataset contains a tally of confirmed and suspected cases in all the countries.
#
# **Worldwide_Case_Detection_Timeline :** This dataset contains the timeline for confirmed cases w.r.t. date time, it also contains some other details on every case that is being reported.
#
# **Daily_Country_Wise_Conformed_Cases :** This dataset contains the daily number of confirmed cases for all the countries where the virus has entered.

# %% [markdown]
# #LETS HAVE A GLIMPSE OF THESE DATASETS .

# %%
print(f"Shape of Case Dataset : {case.shape}")
print(f"\n\nGlimpse of Case Dataset :\n")
case.head()
# Out:
# Shape of Case Dataset : (108, 6)
#
#
# Glimpse of Case Dataset :
#          Country  Confirmed_Cases  Suspected_Cases  Hospitalized  \
# 0        England           2551.0              0.0           5.0
# 1       Portugal            633.0              0.0           0.0
# 2          Spain           4577.0              0.0          13.0
# 3  United States           5793.0              0.0           4.0
# 4         Canada            803.0             15.0           1.0
#
#    Travel_History_Yes  Travel_History_No
# 0                 2.0                7.0
# 1                 0.0               34.0
# 2                 2.0                0.0
# 3                41.0                6.0
# 4                 3.0                0.0

# %%
print(f"Informations of Case Dataset :\n")
print(case.info())
# Out:
# Informations of Case Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             108 non-null    object
#  1   Confirmed_Cases     108 non-null    float64
#  2   Suspected_Cases     108 non-null    float64
#  3   Hospitalized        108 non-null    float64
#  4   Travel_History_Yes  108 non-null    float64
#  5   Travel_History_No   108 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 5.2+ KB
# None

# %% [markdown]
# #Summary of DataSet

# %%
print(f"Summary of Case Dataset :\n")
case.describe().T
# Out:
# Summary of Case Dataset :
#                     count        mean         std  min  25%  50%   75%     max
# Confirmed_Cases     108.0  228.750000  817.351228  0.0  1.0  4.0  36.0  5793.0
# Suspected_Cases     108.0   15.601852  133.225404  0.0  0.0  0.0   0.0  1369.0
# Hospitalized        108.0    1.120370    2.934543  0.0  0.0  0.0   1.0    18.0
# Travel_History_Yes  108.0    2.166667    5.141911  0.0  0.0  1.0   2.0    41.0
# Travel_History_No   108.0    0.740741    3.720040  0.0  0.0  0.0   0.0    34.0

# %%
case.describe(include=object).T
# Out:
#         count unique      top freq
# Country   108    108  England    1

# %%
case.isna().sum().to_frame().T
# Out:
#    Country  Confirmed_Cases  Suspected_Cases  Hospitalized  \
# 0        0                0                0             0
#
#    Travel_History_Yes  Travel_History_No
# 0                   0                  0

# %% [markdown]
# Here, we can see there is **no null value** exists in this dataset. All countable values are in **float** datatype. Let's convert them into **int** datatype for efficient calculation and representation. Before that let's initialize the visualization style and custom pallete for visualization.

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# #1. Check for Missing Values:

# %%
data.isnull().sum()
# Out:
# Date_confirmation          0.0
# Country                    0.0
# City                       0.0
# Age                        0.0
# Gender                     0.0
# Symptoms                   0.0
# Hospitalised (Y/N/NA)      0.0
# Isolated (Y/N/NA)          0.0
# Travel_history (Y/N/NA)    0.0
# dtype: float64

# %% [markdown]
# #2. Fill Missing Values with Mean:

# %%
data.fillna(data.mean(), inplace=True)

# %% [markdown]
# #3.Drop Rows with Missing Values:

# %%
data.dropna(inplace=True)

# %% [markdown]
# #4. Convert Data Types:

# %%
data['Date_confirmation'] = pd.to_datetime(data['Date_confirmation'])

# %% [markdown]
# #5. Remove Duplicates:

# %%
data.drop_duplicates(inplace=True)
# Out:
# Empty DataFrame
# Columns: [Date_confirmation, Country, City, Age, Gender, Symptoms, Hospitalised (Y/N/NA), Isolated (Y/N/NA), Travel_history (Y/N/NA)]
# Index: []

# %% [markdown]
# #6. Filter Data Based on Condition:

# %%
filtered_data = data[data['Age'] > 30]

# %% [markdown]
# #7.Replace Values:

# %%
data['Country'].replace({'Nig3ria': 'Nigeria', 'Cam3roon': 'Cameroon'}, inplace=True)

# %% [markdown]
# #8. Standardize Text Data:

# %%
data['Country'] = data['Country'].str.title()

# %% [markdown]
# #9. Identify and Remove Outliers:

# %%
Q1 = data['Age'].quantile(0.25)
Q3 = data['Age'].quantile(0.75)
IQR = Q3 - Q1
outliers_removed = data[~((data['Age'] < (Q1 - 1.5 * IQR)) | (data['Age'] > (Q3 + 1.5 * IQR)))]

# %% [markdown]
# #10. Handle Categorical Data:

# %%
data = pd.get_dummies(data, columns=['Country'])

# %% [markdown]
# #11. Rename Columns:

# %%
data.rename(columns={'OldName': 'NewName'}, inplace=True)

# %% [markdown]
# #CLEANING THE DATA SET

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the uncleaned CSV file

# %%
file_path = '/content/Worldwide_Case_Detection_Timeline (1).csv'
data = pd.read_csv(file_path)

# %% [markdown]
# # Step 1: Handle missing values
# # Assuming that missing values can be dropped for this scenario

# %%
data.head()
# Out:
#   Date_confirmation   Country City   Age Gender Symptoms  \
# 0        2022-01-31   Nigeria  NaN   NaN    NaN      NaN
# 1        2022-01-31   Nigeria  NaN   NaN    NaN      NaN
# 2        2022-01-31   Nigeria  NaN   NaN    NaN      NaN
# 3        2022-02-17  Cameroon  NaN  0-39    NaN      NaN
# 4        2022-02-17  Cameroon  NaN  0-39    NaN      NaN
#
#   Hospitalised (Y/N/NA) Isolated (Y/N/NA) Travel_history (Y/N/NA)
# 0                   NaN               NaN                     NaN
# 1                   NaN               NaN                     NaN
# 2                   NaN               NaN                     NaN
# 3                   NaN               NaN                     NaN
# 4                   NaN               NaN                     NaN

# %%
data.tail(10)
# Out:
# Empty DataFrame
# Columns: [Date_confirmation, Country, City, Age, Gender, Symptoms, Hospitalised (Y/N/NA), Isolated (Y/N/NA), Travel_history (Y/N/NA)]
# Index: []

# %%
data = data.dropna()

# %% [markdown]
# # Step 2: Correct typos in country names

# %%
corrections = {'Nig3ria': 'Nigeria', 'Cam3roon': 'Cameroon'}
data['Country'] = data['Country'].replace(corrections)

# %% [markdown]
# # Step 3: Ensure the Age column has consistent data types
# # Convert all Age entries to a standard numeric type where possible

# %%
def clean_age(age):
    try:
        return int(age)
    except ValueError:
        if age == 'Thirty-nine':
            return 39
        return np.nan

# %% [markdown]
# # Drop rows where Age conversion failed

# %%
data['Age'] = data['Age'].apply(clean_age)

# %%
data = data.dropna(subset=['Age'])

# %% [markdown]
# # Step 4: Standardize date formats

# %%
data['Date_confirmation'] = pd.to_datetime(data['Date_confirmation'], errors='coerce', infer_datetime_format=True)
# Out:
# <ipython-input-12-709c0dfe3de6>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data['Date_confirmation'] = pd.to_datetime(data['Date_confirmation'], errors='coerce', infer_datetime_format=True)

# %% [markdown]
# # Drop rows where date conversion failed

# %%
data = data.dropna(subset=['Date_confirmation'])

# %% [markdown]
# # Save the cleaned data to a new CSV file

# %%
cleaned_file_path = '/content/Cleaned_Worldwide_Case_Detection_Timeline.csv'
data.to_csv(cleaned_file_path, index=False)

# %%
cleaned_file_path
# Out:
# '/content/Cleaned_Worldwide_Case_Detection_Timeline.csv'

# %%
cleaned_data.head()
# Out:
# Empty DataFrame
# Columns: [Date_confirmation, Country, City, Age, Gender, Symptoms, Hospitalised (Y/N/NA), Isolated (Y/N/NA), Travel_history (Y/N/NA)]
# Index: []

# %% [markdown]
# #DATA VISUALIZATION

# %%
sns.set_style("whitegrid")
sns.set_context("poster",font_scale = .7)

palette = ["#071e22","#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# sns.palplot(sns.color_palette(palette))
# plt.show()

# %% [markdown]
# #DIGGING DEEPER

# %%
print(case["Country"].shape)
print(f'\n There are {len(case["Country"].unique())} contries enlisted here.\n')
case["Country"].unique()
# Out:
# (108,)
#
#  There are 108 contries enlisted here.
# array(['England', 'Portugal', 'Spain', 'United States', 'Canada',
#        'Sweden', 'Italy', 'France', 'Belgium', 'Australia', 'Germany',
#        'Netherlands', 'Israel', 'Switzerland', 'Greece', 'Austria',
#        'Argentina', 'Denmark', 'Morocco', 'Slovenia', 'Scotland',
#        'Czech Republic', 'United Arab Emirates', 'Finland', 'Wales',
#        'Northern Ireland', 'Sudan', 'Bolivia', 'Iran', 'Ecuador', 'Malta',
#        'Ireland', 'Mexico', 'Pakistan', 'French Guiana', 'Thailand',
#        'Peru', 'Brazil', 'Malaysia', 'Hungary', 'Norway', 'Paraguay',
#        'Costa Rica', 'Gibraltar', 'Mauritius', 'Haiti', 'Uruguay',
#        'Latvia', 'Cayman Islands', 'Kosovo', 'Turkey', 'Bahamas', 'Ghana',
#        'India', 'Iceland', 'Poland', 'Bangladesh', 'Uganda', 'Cambodia',
#        'Malawi', 'Venezuela', 'Romania', 'Georgia', 'Slovakia',
#        'Luxembourg', 'Nepal', 'Chile', 'Serbia', 'Lebanon', 'South Korea',
#        'Singapore', 'South Africa', 'Taiwan', 'Colombia', 'Croatia',
#        'Bulgaria', 'Somalia', 'Zambia', 'Fiji', 'Benin', 'Estonia',
#        'Puerto Rico', 'Panama', 'Dominican Republic', 'Jamaica',
#        'New Zealand', 'Russia', 'Bosnia And Herzegovina', 'Saudi Arabia',
#        'Martinique', 'Barbados', 'Qatar', 'Bermuda', 'Japan',
#        'Guadeloupe', 'Andorra', 'New Caledonia', 'China', 'Philippines',
#        'Montenegro', 'Cyprus', 'Nigeria',
#        'Democratic Republic Of The Congo', 'Central African Republic',
#        'Republic of Congo', 'Cameroon', 'Liberia', 'Sierra Leone'],
#       dtype=object)

# %%
case[["Confirmed_Cases","Suspected_Cases","Hospitalized","Travel_History_Yes","Travel_History_No"]] = case[["Confirmed_Cases","Suspected_Cases","Hospitalized","Travel_History_Yes","Travel_History_No"]].astype("int")
case["Total_Cases"] = case[["Confirmed_Cases","Suspected_Cases"]].sum(axis=1)

case_temp1 = case.sort_values(["Confirmed_Cases"],ascending=False)
case_temp2 = case.sort_values(["Suspected_Cases"],ascending=False)



_, axs = plt.subplots(1,2,figsize=(20,8))
plt.tight_layout(pad=4.0)


sns.barplot(x=case_temp1["Country"][:15],y=case_temp1["Confirmed_Cases"],ax=axs[0],palette=palette, saturation=1)
axs[0].set_ylabel("Total Confirmed Cases")
axs[0].set_xticklabels(axs[0].get_xticklabels(),rotation = 90)
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="edge",padding=2,size=15,color="black",rotation=90)


sns.barplot(x=case_temp2["Country"][:15],y=case_temp2["Suspected_Cases"],ax=axs[1],palette=palette, saturation=1)
axs[1].set_ylabel("Total Suspected Cases")
axs[1].set_xticklabels(axs[1].get_xticklabels(),rotation = 90)
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="edge",padding=2,size=15,color="black",rotation=90)

plt.suptitle("Countries Contaminated With Monkeypox\n",fontsize=20)
sns.despine(left=True, bottom=True)
plt.show()
# Out:
# <ipython-input-10-cb15ec98e6be>:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-10-cb15ec98e6be>:15: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# <ipython-input-10-cb15ec98e6be>:20: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-10-cb15ec98e6be>:22: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# We can see that **United States** is leading in confirmed cases followed by **Spain**, **Germany** and others. Meanwhile **Democratic Republic of The Congo** is leading in suspected cases followed by **Nigeria**, **Cameroon** and rest. Top 15 countries have been taken for both confirmed cases and suspected cases for better visualization.

# %%
case_temp3 = case.sort_values(["Total_Cases"],ascending=False)

plt.subplots(figsize=(20,10))
p = sns.barplot(x=case_temp3["Country"][:15],y=case_temp3["Total_Cases"],palette=palette, saturation=1)
p.axes.set_title("\nCountries Contaminated With Monkeypox\n",fontsize=20)
plt.ylabel("Total Cases")
plt.xticks(rotation=90)
for container in p.containers:
    p.bar_label(container,label_type="center",padding=2,size=15,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# <ipython-input-11-e4b13469d9d8>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Though **Democratic Republic of The Congo** is leading in suspected cases, **United States** is leading in overall cases followed by **Spain**, **Germany** and rest. Top 15 countries have been taken for better visualization.

# %% [markdown]
# #Exploring Hospitalized Patient

# %%
case_temp3_temp = case.sort_values(["Total_Cases"],ascending=False)[:15]

case_temp3_melt = case_temp3_temp.melt(id_vars=['Country'], value_vars=["Total_Cases","Hospitalized"],
                  var_name="Variables", value_name="Values")

plt.subplots(figsize=(20,15))
p = sns.barplot(y=case_temp3_melt["Country"],x=case_temp3_melt["Values"],hue=case_temp3_melt["Variables"],palette=["#1d7874","#ffd100"], saturation=1)
p.axes.set_title("\nTop Contaminated Countries' Hospitalized Ratio\n",fontsize=20)
plt.ylabel("Country")
plt.xlabel("Cases")
plt.xticks(rotation=0)
for container in p.containers:
    p.bar_label(container,label_type="edge",padding=2,size=15,color="black",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# We can see **United States** is leading in overall number of cases but the number of hospitalized cases are not high whereas **Germany** is leading in hospitalized cases. Also **Italy** is moving forward with **Germany** in the number of hospitalized cases though the number of overall cases is not too high yet.

# %%
case_temp4 = case.sort_values(["Hospitalized"],ascending=False)

plt.subplots(figsize=(20,10))
p = sns.barplot(x=case_temp4["Country"][:15],y=case_temp4["Hospitalized"],palette=palette, saturation=1)
p.axes.set_title("\nCountry-wise Hospitalized Cases\n",fontsize=20)
plt.ylabel("Total Cases")
plt.xticks(rotation=90)
for container in p.containers:
    p.bar_label(container,label_type="center",padding=2,size=18,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# <ipython-input-13-1a34d440e9e7>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# We can see the number of hospitalized cases are not high yet. **Italy** and **Germany** are leading in hospitalized cases followed by **Spain**, **Singapore** and rest. Top 15 countries have been taken for better visualization.

# %% [markdown]
# #**Exploring Travel History**

# %%
case["Travel_History"] = case[["Travel_History_Yes","Travel_History_No"]].sum(axis=1)
case_temp5 = case.sort_values(["Travel_History"],ascending=False)[:15]

case_temp5_melt = case_temp5.melt(id_vars=['Country'], value_vars=["Travel_History_Yes","Travel_History_No"],
                  var_name="Variables", value_name="Values")

plt.subplots(figsize=(20,10))
p = sns.barplot(x=case_temp5_melt["Country"],y=case_temp5_melt["Values"],hue=case_temp5_melt["Variables"],palette=["#333533","#ffd100"], saturation=1)
p.axes.set_title("\nCountry-wise Travel History\n",fontsize=20)
plt.xlabel("Country")
plt.ylabel("Cases")
plt.xticks(rotation=90)
for container in p.containers:
    p.bar_label(container,label_type="edge",padding=2,size=15,color="black",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# We can see the travel history is also rich for **United States**, **Germany**, **Italy** and **Brazil**.

# %% [markdown]
# #**Exploring Monkeypox Symptoms**

# %%
symptoms = case_timeline[["Symptoms"]]
symptoms["Symptoms"].replace(np.nan,"NA",inplace = True)
symptoms = symptoms[symptoms["Symptoms"].isin(["NA"]) == False]
symptoms["Symptoms"] = symptoms["Symptoms"].str.split(", | , | ,|;")
symptoms = symptoms.explode("Symptoms")

symptoms.replace(to_replace = [" rash","rash","rashes","vesicular rash","Rashes","rash on the skin","vasicular rashes","rashes in the groin area","rashes typical of Monkeypox","Rashes in the perianal region","skin rashes","Genital rashes","genital rash"], value = "Rash", inplace=True)
symptoms.replace(to_replace = ["headache","headaches"], value = "Headache", inplace=True)
symptoms.replace(to_replace = ["genital ulcers"], value = "oral and genital ulcers", inplace=True)
symptoms.replace(to_replace = ["muscle pain","muscle ache","back pain","body pains"], value = "Muscle Pain", inplace=True)
symptoms.replace(to_replace = ["Swelling","swelling of lymph nodes","enlarged lymph nodes","Slight swallowing difficulties and an elevated temperature"], value = "swollen lymph nodes", inplace=True)
symptoms.replace(to_replace = ["lesions","skin manifestations","isolated skin lesions","lower abdomen skin lesions","Spots on skin","Three lesions typical of monkeypox"], value = "skin lesions", inplace=True)
symptoms.replace(to_replace = ["fever","mild fever","high fever"], value = "Fever", inplace=True)
symptoms.replace(to_replace = ["fatigue"," myalgia","vesicles"," inguinal adenopathy"], value = ["Fatigue","myalgia","Vesicles","inguinal adenopathy"], inplace=True)
symptoms["Symptoms"] = symptoms["Symptoms"].str.title()

# import warnings
# warnings.filterwarnings("ignore")
print(f'Total amount of unique symptoms : {len(symptoms["Symptoms"].unique())}')
print("\nTop 15 unique symptoms and respective occurances are :\n\n")
symptoms["Symptoms"].value_counts()[:15].to_frame().T
# Out:
# <ipython-input-15-f699b99e618a>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Total amount of unique symptoms : 41
#
# Top 15 unique symptoms and respective occurances are :
# Symptoms  Fever  Rash  Genital Ulcer Lesions  Skin Lesions  \
# count        53    43                     30            25
#
# Symptoms  Oral And Genital Ulcers  Ulcerative Lesions  Headache  Fatigue  \
# count                          22                  21        12       10
#
# Symptoms  Muscle Pain  Swollen Lymph Nodes  Sore Throat  Myalgias  Myalgia  \
# count               6                    6            3         3        3
#
# Symptoms  Blisters  Cough
# count            3      2

# %%
data = {
    'Symptoms': ['Fever', 'Rash', 'Headache', 'Fever', 'Rash', 'Headache', 'Fever', 'Fatigue', 'Nausea', 'Cough', 'Fever', 'Rash', 'Headache', 'Fatigue', 'Nausea', 'Cough']
}
symptoms = pd.DataFrame(data)

# Set the plot size and style
plt.subplots(figsize=(20, 8))
p=sns.countplot(x=symptoms["Symptoms"] ,order=symptoms["Symptoms"].value_counts().index[:10],palette=palette, saturation=1)

p.axes.set_title("\nSymptom-wise Occurances\n",fontsize=20)
plt.ylabel("Total Occurances")
plt.xlabel("Symptoms")
plt.xticks(rotation=90)
for container in p.containers:
    p.bar_label(container,label_type="center",padding=2,size=20,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# <ipython-input-44-8e684b61e260>:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-44-8e684b61e260>:8: UserWarning:
#
# The palette list has more values (10) than needed (6), which may not be intended.

# %% [markdown]
# We can see among all symptoms **fever**, **genital ulcer lesions**, **rash**, **oral and genital ulcers**, **ulcerative lesions**, **skin lesions** are frequently enlisted. Top 10 frequent symptoms have been taken here for better visualization.

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 160,
            background_color ="black",colormap="RdYlGn",max_font_size=40).generate(str(symptoms["Symptoms"].values))

plt.figure(figsize = (20, 8),facecolor= "#ffd100")
plt.imshow(wordcloud)
plt.axis("off")
plt.margins(x=0, y=0)
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# #**Exploring Case Timeline**

# %%
case_country.set_index("Country",inplace = True)
timeline = case_country.T
timeline.head(5)
# Out:
# Country     Nigeria  Cameroon  Central African Republic  Republic of Congo  \
# 2022-01-31        3         0                         0                  0
# 2022-02-17        0         3                         0                  0
# 2022-02-28        1         0                         0                  0
# 2022-03-04        0         0                         2                  0
# 2022-03-31        6         0                         0                  0
#
# Country     England  Democratic Republic Of The Congo  Portugal  Spain  \
# 2022-01-31        0                                 0         0      0
# 2022-02-17        0                                 0         0      0
# 2022-02-28        0                                 0         0      0
# 2022-03-04        0                                 0         0      0
# 2022-03-31        0                                 0         0      0
#
# Country     United States  Belgium  ...  Thailand  Andorra  Guadeloupe  Japan  \
# 2022-01-31              0        0  ...         0        0           0      0
# 2022-02-17              0        0  ...         0        0           0      0
# 2022-02-28              0        0  ...         0        0           0      0
# 2022-03-04              0        0  ...         0        0           0      0
# 2022-03-31              0        0  ...         0        0           0      0
#
# Country     Philippines  Uruguay  Sudan  Bolivia  Montenegro  Cyprus
# 2022-01-31            0        0      0        0           0       0
# 2022-02-17            0        0      0        0           0       0
# 2022-02-28            0        0      0        0           0       0
# 2022-03-04            0        0      0        0           0       0
# 2022-03-31            0        0      0        0           0       0
#
# [5 rows x 88 columns]

# %%
_, axs = plt.subplots(3,3,figsize=(25,20),sharex=True)
plt.tight_layout(pad=4.0)

sns.lineplot(x=timeline.index ,y="Spain",data=timeline,ax=axs[0,0],color="#0f4c5c")
axs[0,0].set_title("\nConfirmed Cases of Spain\n",fontsize=20)
axs[0,0].set_xlabel("Days")
axs[0,0].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="United States",data=timeline,ax=axs[0,1],color="#FFC300")
axs[0,1].set_title("\nConfirmed Cases of United States\n",fontsize=20)
axs[0,1].set_xlabel("Days")
axs[0,1].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="Germany",data=timeline,ax=axs[0,2],color="#7C7C7C")
axs[0,2].set_title("\nConfirmed Cases of Germany\n",fontsize=20)
axs[0,2].set_xlabel("Days")
axs[0,2].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="England",data=timeline,ax=axs[1,0],color="#5f0f40")
axs[1,0].set_title("\nConfirmed Cases of England\n",fontsize=20)
axs[1,0].set_xlabel("Days")
axs[1,0].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="France",data=timeline,ax=axs[1,1],color="#f85e00")
axs[1,1].set_title("\nConfirmed Cases of France\n",fontsize=20)
axs[1,1].set_xlabel("Days")
axs[1,1].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="Netherlands",data=timeline,ax=axs[1,2],color="#9a031e")
axs[1,2].set_title("\nConfirmed Cases of Netherlands\n",fontsize=20)
axs[1,2].set_xlabel("Days")
axs[1,2].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="Canada",data=timeline,ax=axs[2,0],color="#918450")
axs[2,0].set_title("\nConfirmed Cases of Canada\n",fontsize=20)
axs[2,0].set_xlabel("Days")
axs[2,0].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="Portugal",data=timeline,ax=axs[2,1],color="#1d7874")
axs[2,1].set_title("\nConfirmed Cases of Portugal\n",fontsize=20)
axs[2,1].set_xlabel("Days")
axs[2,1].set_ylabel("Number of Patients")

sns.lineplot(x=timeline.index ,y="Brazil",data=timeline,ax=axs[2,2],color="#333533")
axs[2,2].set_title("\nConfirmed Cases of Brazil\n",fontsize=20)
axs[2,2].set_xlabel("Days")
axs[2,2].set_ylabel("Number of Patients")
axs[2,2].set_xticks([],minor=False)

sns.despine(left=True, bottom=True)
plt.show()

# %%
_, axs = plt.subplots(figsize=(20,10))
plt.tight_layout(pad=4.0)

sns.lineplot(x=timeline.index ,y=timeline["Spain"].cumsum(axis=0),data=timeline,ax=axs,color="#0f4c5c")
sns.lineplot(x=timeline.index ,y=timeline["United States"].cumsum(axis=0),data=timeline,ax=axs,color="#FFC300")
sns.lineplot(x=timeline.index ,y=timeline["Germany"].cumsum(axis=0),data=timeline,ax=axs,color="#7C7C7C")
sns.lineplot(x=timeline.index ,y=timeline["England"].cumsum(axis=0),data=timeline,ax=axs,color="#5f0f40")
sns.lineplot(x=timeline.index ,y=timeline["France"].cumsum(axis=0),data=timeline,ax=axs,color="#f85e00")
sns.lineplot(x=timeline.index ,y=timeline["Netherlands"].cumsum(axis=0),data=timeline,ax=axs,color="#9a031e")
sns.lineplot(x=timeline.index ,y=timeline["Canada"].cumsum(axis=0),data=timeline,ax=axs,color="#918450")
sns.lineplot(x=timeline.index ,y=timeline["Portugal"].cumsum(axis=0),data=timeline,ax=axs,color="#1d7874")
sns.lineplot(x=timeline.index ,y=timeline["Brazil"].cumsum(axis=0),data=timeline,ax=axs,color="#333533")

axs.set_title("\nConfirmed Cases of Spain\n",fontsize=20)
axs.set_xlabel("Days")
axs.set_ylabel("Number of Patients")
axs.legend(["Spain","United States","Germany","England","France","Netherlands","Canada","Portugal","Brazil"])
axs.set_xticks([],minor=False)
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# We can see the directions of top 9 countries contaminated with monkeypox. All of them are moving upwards gradually leading by **United States** followed by **Spain** and rest. We can say that **tough days are coming** for this countries!!

# %% [markdown]
# #**Custom Palette For Visualizing Origins**

# %%
palette_map = ["#FFBA08","#FAA307","#F48C06","#E85D04","#DC2F02","#D00000","#9D0208","#6A040F","#370617","#03071E"]

sns.palplot(sns.color_palette(palette_map))
plt.show()

# %%
palette_cmap = ["#480838","#580838","#600840","#680840","#7e002f","#8c0034","#900C3F","#9D0208","#D00000","#DC2F02","#E85D04","#F48C06","#F5B301","#FFC300","#FED053","#7C7C7C","#3B3F46","#2A2E34","#1E2328"]

sns.palplot(sns.color_palette(palette_cmap))
plt.show()

# %%
plt.subplots(figsize=(10, 8))

sns.heatmap(case.drop(columns=["Country", "Total_Cases", "Travel_History"]).corr(),
            cmap=palette_cmap, square=True, cbar_kws=dict(shrink=.95),
            annot=True, vmin=-1, vmax=1, linewidths=0.1, linecolor='white', annot_kws=dict(fontsize=12))

plt.title("Pearson Correlation Of Features\n", size=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can see that **people with travel history** have a **positive correlation** with the **confirmed cases** and **hospitalization**!!

# %% [markdown]
# #conclusion
#
# the analysis of monkeypox is essential for understanding its epidemiology, transmission dynamics, and potential impacts on public health. Through rigorous examination of cases, risk factors, and genetic sequencing, researchers can identify patterns of spread, assess the effectiveness of control measures, and develop targeted interventions to mitigate its spread. Additionally, ongoing surveillance and monitoring efforts are crucial for early detection and response to outbreaks, thereby reducing the risk of widespread transmission. By employing multidisciplinary approaches that integrate epidemiological, clinical, and genomic data, we can enhance our understanding of monkeypox and strengthen our ability to prevent, detect, and control this infectious disease.

# %% [markdown]
# #**Thankyou**
